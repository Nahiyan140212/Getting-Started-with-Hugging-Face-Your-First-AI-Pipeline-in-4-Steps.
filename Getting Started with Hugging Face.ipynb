# %% [markdown]
# ## Using Hugging Face Hub

# %%
from huggingface_hub import HfApi

# %%
api = HfApi()

# %%
list(api.list_models())
# Out:
# [ModelInfo(id='perplexity-ai/r1-1776', author=None, sha=None, created_at=datetime.datetime(2025, 2, 18, 0, 13, 5, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=6438, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=1369, library_name=None, tags=['safetensors', 'deepseek_v3', 'custom_code', 'base_model:deepseek-ai/DeepSeek-R1', 'base_model:finetune:deepseek-ai/DeepSeek-R1', 'license:mit', 'region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=1369, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='deepseek-ai/DeepSeek-R1', author=None, sha=None, created_at=datetime.datetime(2025, 1, 20, 3, 46, 7, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=4351443, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=9887, library_name='transformers', tags=['transformers', 'safetensors', 'deepseek_v3', 'text-generation', 'conversational', 'custom_code', 'arxiv:2501.12948', 'license:mit', 'autotrain_compatible', 'fp8', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=1028, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='microsoft/OmniParser-v2.0', author=None, sha=None, created_at=datetime.datetime(2025, 2, 12, 1, 3, 38, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=3581, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=830, library_name='transformers', tags=['transformers', 'safetensors', 'image-text-to-text', 'arxiv:2408.00203', 'license:mit', 'endpoints_compatible', 'region:us'], pipeline_tag='image-text-to-text', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=772, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='stepfun-ai/Step-Audio-Chat', author=None, sha=None, created_at=datetime.datetime(2025, 2, 13, 14, 48, 2, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=544, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=335, library_name=None, tags=['safetensors', 'step1', 'audio-text-to-text', 'custom_code', 'license:apache-2.0', 'region:us'], pipeline_tag='audio-text-to-text', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=331, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='stepfun-ai/stepvideo-t2v', author=None, sha=None, created_at=datetime.datetime(2025, 2, 14, 2, 43, 54, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=800, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=280, library_name='diffusers', tags=['diffusers', 'safetensors', 'text-to-video', 'arxiv:2502.10248', 'license:mit', 'diffusers:StepVideoPipeline', 'region:us'], pipeline_tag='text-to-video', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=280, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Zyphra/Zonos-v0.1-hybrid', author=None, sha=None, created_at=datetime.datetime(2025, 2, 6, 22, 35, 7, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=21683, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=969, library_name=None, tags=['safetensors', 'text-to-speech', 'license:apache-2.0', 'region:us'], pipeline_tag='text-to-speech', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=208, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='black-forest-labs/FLUX.1-dev', author=None, sha=None, created_at=datetime.datetime(2024, 7, 31, 21, 13, 44, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=1818799, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=8926, library_name='diffusers', tags=['diffusers', 'safetensors', 'text-to-image', 'image-generation', 'flux', 'en', 'license:other', 'endpoints_compatible', 'diffusers:FluxPipeline', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=204, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='hexgrad/Kokoro-82M', author=None, sha=None, created_at=datetime.datetime(2024, 12, 26, 0, 20, 8, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=968170, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=3336, library_name=None, tags=['text-to-speech', 'en', 'arxiv:2306.07691', 'arxiv:2203.02395', 'base_model:yl4579/StyleTTS2-LJSpeech', 'base_model:finetune:yl4579/StyleTTS2-LJSpeech', 'doi:10.57967/hf/4329', 'license:apache-2.0', 'region:us'], pipeline_tag='text-to-speech', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=194, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Skywork/SkyReels-V1-Hunyuan-I2V', author=None, sha=None, created_at=datetime.datetime(2025, 2, 17, 3, 52, 30, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=13681, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=176, library_name='diffusers', tags=['diffusers', 'safetensors', 'image-to-video', 'en', 'base_model:tencent/HunyuanVideo', 'base_model:finetune:tencent/HunyuanVideo', 'region:us'], pipeline_tag='image-to-video', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=176, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='smirki/UIGEN-T1-Qwen-7b', author=None, sha=None, created_at=datetime.datetime(2025, 2, 16, 8, 59, 7, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=9640, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=171, library_name=None, tags=['gguf', 'code', 'text-generation', 'en', 'dataset:smirki/UI_Reasoning_Dataset', 'base_model:Qwen/Qwen2.5-Coder-7B-Instruct', 'base_model:quantized:Qwen/Qwen2.5-Coder-7B-Instruct', 'license:apache-2.0', 'endpoints_compatible', 'region:us', 'conversational'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=171, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='microsoft/wham', author=None, sha=None, created_at=datetime.datetime(2025, 2, 11, 15, 9, 59, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=0, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=157, library_name=None, tags=['wham', 'microsoft', 'en', 'dataset:microsoft/bleeding-edge-gameplay-sample', 'region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=157, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='agentica-org/DeepScaleR-1.5B-Preview', author=None, sha=None, created_at=datetime.datetime(2025, 1, 29, 10, 58, 40, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=14543, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=462, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2', 'text-generation', 'en', 'dataset:AI-MO/NuminaMath-CoT', 'dataset:KbsdJames/Omni-MATH', 'dataset:RUC-AIBOX/STILL-3-Preview-RL-Data', 'dataset:hendrycks/competition_math', 'base_model:deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B', 'base_model:finetune:deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B', 'license:mit', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=143, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='NousResearch/DeepHermes-3-Llama-3-8B-Preview', author=None, sha=None, created_at=datetime.datetime(2025, 2, 12, 4, 9, 45, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=5380, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=252, library_name='transformers', tags=['transformers', 'safetensors', 'llama', 'text-generation', 'Llama-3', 'instruct', 'finetune', 'chatml', 'gpt4', 'synthetic data', 'distillation', 'function calling', 'json mode', 'axolotl', 'roleplaying', 'chat', 'reasoning', 'r1', 'vllm', 'conversational', 'en', 'base_model:meta-llama/Llama-3.1-8B', 'base_model:finetune:meta-llama/Llama-3.1-8B', 'license:llama3', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=139, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='deepseek-ai/Janus-Pro-7B', author=None, sha=None, created_at=datetime.datetime(2025, 1, 26, 12, 5, 50, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=464657, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=3081, library_name='transformers', tags=['transformers', 'pytorch', 'multi_modality', 'muiltimodal', 'text-to-image', 'unified-model', 'any-to-any', 'arxiv:2501.17811', 'license:mit', 'endpoints_compatible', 'region:us'], pipeline_tag='any-to-any', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=128, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='ValueFX9507/Tifa-DeepsexV2-7b-MGRPO-GGUF-Q4', author=None, sha=None, created_at=datetime.datetime(2025, 2, 13, 14, 49, 7, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=29646, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=184, library_name='transformers', tags=['transformers', 'gguf', 'incremental-pretraining', 'sft', 'reinforcement-learning', 'roleplay', 'cot', 'zh', 'en', 'license:apache-2.0', 'endpoints_compatible', 'region:us', 'conversational'], pipeline_tag='reinforcement-learning', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=118, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='stepfun-ai/Step-Audio-TTS-3B', author=None, sha=None, created_at=datetime.datetime(2025, 2, 13, 14, 49, 26, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=827, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=116, library_name=None, tags=['onnx', 'safetensors', 'step1', 'text-to-speech', 'custom_code', 'license:apache-2.0', 'region:us'], pipeline_tag='text-to-speech', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=116, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='deepseek-ai/DeepSeek-V3', author=None, sha=None, created_at=datetime.datetime(2024, 12, 25, 12, 52, 23, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=2489908, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=3520, library_name='transformers', tags=['transformers', 'safetensors', 'deepseek_v3', 'text-generation', 'conversational', 'custom_code', 'arxiv:2412.19437', 'autotrain_compatible', 'fp8', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=108, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='zed-industries/zeta', author=None, sha=None, created_at=datetime.datetime(2025, 1, 30, 15, 21, 48, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=865, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=189, library_name=None, tags=['safetensors', 'qwen2', 'dataset:zed-industries/zeta', 'license:apache-2.0', 'region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=106, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='nomic-ai/nomic-embed-text-v2-moe', author=None, sha=None, created_at=datetime.datetime(2025, 2, 7, 22, 50, 7, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=23137, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=234, library_name='sentence-transformers', tags=['sentence-transformers', 'safetensors', 'nomic_bert', 'sentence-similarity', 'feature-extraction', 'custom_code', 'en', 'es', 'fr', 'de', 'it', 'pt', 'pl', 'nl', 'tr', 'ja', 'vi', 'ru', 'id', 'ar', 'cs', 'ro', 'sv', 'el', 'uk', 'zh', 'hu', 'da', 'no', 'hi', 'fi', 'bg', 'ko', 'sk', 'th', 'he', 'ca', 'lt', 'fa', 'ms', 'sl', 'lv', 'mr', 'bn', 'sq', 'cy', 'be', 'ml', 'kn', 'mk', 'ur', 'fy', 'te', 'eu', 'sw', 'so', 'sd', 'uz', 'co', 'hr', 'gu', 'ce', 'eo', 'jv', 'la', 'zu', 'mn', 'si', 'ga', 'ky', 'tg', 'my', 'km', 'mg', 'pa', 'sn', 'ha', 'ht', 'su', 'gd', 'ny', 'ps', 'ku', 'am', 'ig', 'lo', 'mi', 'nn', 'sm', 'yi', 'st', 'tl', 'xh', 'yo', 'af', 'ta', 'tn', 'ug', 'az', 'ba', 'bs', 'dv', 'et', 'gl', 'gn', 'gv', 'hy', 'arxiv:2205.13147', 'arxiv:2502.07972', 'base_model:nomic-ai/nomic-embed-text-v2-moe-unsupervised', 'base_model:finetune:nomic-ai/nomic-embed-text-v2-moe-unsupervised', 'license:apache-2.0', 'autotrain_compatible', 'text-embeddings-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='sentence-similarity', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=105, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='unsloth/DeepSeek-R1-GGUF', author=None, sha=None, created_at=datetime.datetime(2025, 1, 20, 13, 9, 42, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=2465520, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=884, library_name='transformers', tags=['transformers', 'gguf', 'deepseek_v3', 'text-generation', 'deepseek', 'unsloth', 'custom_code', 'en', 'arxiv:2501.12948', 'base_model:deepseek-ai/DeepSeek-R1', 'base_model:quantized:deepseek-ai/DeepSeek-R1', 'license:mit', 'autotrain_compatible', 'endpoints_compatible', 'region:us', 'conversational'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=104, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Zyphra/Zonos-v0.1-transformer', author=None, sha=None, created_at=datetime.datetime(2025, 2, 6, 22, 32, 45, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=69485, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=344, library_name=None, tags=['safetensors', 'text-to-speech', 'license:apache-2.0', 'region:us'], pipeline_tag='text-to-speech', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=104, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='deepseek-ai/DeepSeek-R1-Distill-Qwen-32B', author=None, sha=None, created_at=datetime.datetime(2025, 1, 20, 9, 19, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=972768, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=1146, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2', 'text-generation', 'conversational', 'arxiv:2501.12948', 'license:mit', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=100, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B', author=None, sha=None, created_at=datetime.datetime(2025, 1, 20, 9, 4, 18, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=1075846, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=905, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2', 'text-generation', 'conversational', 'arxiv:2501.12948', 'license:mit', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=94, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Qwen/Qwen2.5-VL-7B-Instruct', author=None, sha=None, created_at=datetime.datetime(2025, 1, 26, 9, 26, 37, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=1454721, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=516, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2_5_vl', 'image-text-to-text', 'multimodal', 'conversational', 'en', 'arxiv:2309.00071', 'arxiv:2409.12191', 'arxiv:2308.12966', 'license:apache-2.0', 'endpoints_compatible', 'region:us'], pipeline_tag='image-text-to-text', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=94, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='stabilityai/stable-diffusion-3.5-large', author=None, sha=None, created_at=datetime.datetime(2024, 10, 22, 7, 29, 57, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=274462, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=2297, library_name='diffusers', tags=['diffusers', 'safetensors', 'text-to-image', 'stable-diffusion', 'en', 'arxiv:2403.03206', 'license:other', 'diffusers:StableDiffusion3Pipeline', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=93, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='meta-llama/Llama-3.2-3B-Instruct', author=None, sha=None, created_at=datetime.datetime(2024, 9, 18, 15, 19, 20, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=1603089, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=1087, library_name='transformers', tags=['transformers', 'safetensors', 'llama', 'text-generation', 'facebook', 'meta', 'pytorch', 'llama-3', 'conversational', 'en', 'de', 'fr', 'it', 'pt', 'hi', 'es', 'th', 'arxiv:2204.05149', 'arxiv:2405.16406', 'license:llama3.2', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=88, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Kijai/SkyReels-V1-Hunyuan_comfy', author=None, sha=None, created_at=datetime.datetime(2025, 2, 18, 1, 23, 8, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=17746, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=88, library_name=None, tags=['gguf', 'region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=88, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='meta-llama/Llama-3.3-70B-Instruct', author=None, sha=None, created_at=datetime.datetime(2024, 11, 26, 16, 8, 47, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=492620, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=2012, library_name='transformers', tags=['transformers', 'safetensors', 'llama', 'text-generation', 'facebook', 'meta', 'pytorch', 'llama-3', 'conversational', 'en', 'fr', 'it', 'pt', 'hi', 'es', 'th', 'de', 'arxiv:2204.05149', 'base_model:meta-llama/Llama-3.1-70B', 'base_model:finetune:meta-llama/Llama-3.1-70B', 'license:llama3.3', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=83, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='tencent/Hunyuan3D-2', author=None, sha=None, created_at=datetime.datetime(2025, 1, 20, 6, 55, 37, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=65802, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=978, library_name='hunyuan3d-2.0', tags=['hunyuan3d-2.0', 'diffusers', 'safetensors', 'image-to-3d', 'text-to-3d', 'en', 'zh', 'arxiv:2501.12202', 'arxiv:2411.02293', 'license:other', 'region:us'], pipeline_tag='image-to-3d', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=82, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='NexaAIDev/DeepSeek-R1-Distill-Llama-8B-NexaQuant', author=None, sha=None, created_at=datetime.datetime(2025, 2, 6, 0, 54, 15, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=3376, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=76, library_name='transformers', tags=['transformers', 'gguf', 'deepseek', 'llama', 'llama-3', 'meta', 'GGUF', 'base_model:deepseek-ai/DeepSeek-R1-Distill-Llama-8B', 'base_model:quantized:deepseek-ai/DeepSeek-R1-Distill-Llama-8B', 'license:llama3.1', 'endpoints_compatible', 'region:us', 'conversational'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=76, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='open-thoughts/OpenThinker-32B', author=None, sha=None, created_at=datetime.datetime(2025, 2, 12, 16, 29, 31, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=1977, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=144, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2', 'text-generation', 'llama-factory', 'full', 'generated_from_trainer', 'conversational', 'dataset:open-thoughts/open-thoughts-114k', 'base_model:Qwen/Qwen2.5-32B-Instruct', 'base_model:finetune:Qwen/Qwen2.5-32B-Instruct', 'license:apache-2.0', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=75, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='tomg-group-umd/huginn-0125', author=None, sha=None, created_at=datetime.datetime(2025, 1, 8, 11, 12, 38, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=9292, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=223, library_name='transformers', tags=['transformers', 'safetensors', 'huginn_raven', 'text-generation', 'code', 'math', 'reasoning', 'llm', 'conversational', 'custom_code', 'en', 'arxiv:2502.05171', 'license:apache-2.0', 'autotrain_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=73, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='NexaAIDev/DeepSeek-R1-Distill-Qwen-1.5B-NexaQuant', author=None, sha=None, created_at=datetime.datetime(2025, 2, 5, 20, 41, 37, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=4167, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=71, library_name='transformers', tags=['transformers', 'gguf', 'deepseek', 'qwen', 'qwen2', 'GGUF', 'base_model:deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B', 'base_model:quantized:deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B', 'license:apache-2.0', 'endpoints_compatible', 'region:us', 'conversational'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=71, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='agents-course/notebooks', author=None, sha=None, created_at=datetime.datetime(2025, 2, 10, 17, 2, 18, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=0, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=98, library_name=None, tags=['license:apache-2.0', 'region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=66, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='ValueFX9507/Tifa-DeepsexV2-7b-MGRPO-GGUF-Q8', author=None, sha=None, created_at=datetime.datetime(2025, 2, 15, 13, 30, 54, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=65201, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=66, library_name='transformers', tags=['transformers', 'gguf', 'incremental-pretraining', 'sft', 'reinforcement-learning', 'roleplay', 'cot', 'zh', 'en', 'license:apache-2.0', 'endpoints_compatible', 'region:us', 'conversational'], pipeline_tag='reinforcement-learning', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=66, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='stepfun-ai/stepvideo-t2v-turbo', author=None, sha=None, created_at=datetime.datetime(2025, 2, 12, 6, 10, 3, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=0, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=65, library_name='diffusers', tags=['diffusers', 'safetensors', 'arxiv:2502.10248', 'license:mit', 'region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=65, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='unsloth/r1-1776-GGUF', author=None, sha=None, created_at=datetime.datetime(2025, 2, 18, 23, 0, 25, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=15846, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=62, library_name='transformers', tags=['transformers', 'gguf', 'deepseek_v3', 'text-generation', 'deepseek', 'unsloth', 'custom_code', 'en', 'base_model:perplexity-ai/r1-1776', 'base_model:quantized:perplexity-ai/r1-1776', 'license:mit', 'autotrain_compatible', 'endpoints_compatible', 'region:us', 'conversational'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=62, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='mistralai/Mistral-Small-24B-Instruct-2501', author=None, sha=None, created_at=datetime.datetime(2025, 1, 28, 13, 30, 13, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=728715, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=804, library_name='vllm', tags=['vllm', 'safetensors', 'mistral', 'text-generation', 'transformers', 'conversational', 'en', 'fr', 'de', 'es', 'it', 'pt', 'zh', 'ja', 'ru', 'ko', 'base_model:mistralai/Mistral-Small-24B-Base-2501', 'base_model:finetune:mistralai/Mistral-Small-24B-Base-2501', 'license:apache-2.0', 'text-generation-inference', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=61, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='microsoft/OmniParser', author=None, sha=None, created_at=datetime.datetime(2024, 10, 7, 23, 32, 7, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=2738, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=1611, library_name='transformers', tags=['transformers', 'safetensors', 'blip-2', 'visual-question-answering', 'image-text-to-text', 'arxiv:2408.00203', 'license:mit', 'endpoints_compatible', 'region:us'], pipeline_tag='image-text-to-text', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=60, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='tencent/HunyuanVideo', author=None, sha=None, created_at=datetime.datetime(2024, 12, 1, 6, 0, 34, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=7961, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=1674, library_name=None, tags=['text-to-video', 'arxiv:2412.03603', 'arxiv:2405.07719', 'license:other', 'region:us'], pipeline_tag='text-to-video', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=59, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='openai/whisper-large-v3-turbo', author=None, sha=None, created_at=datetime.datetime(2024, 10, 1, 7, 39, 28, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=10048816, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=2007, library_name='transformers', tags=['transformers', 'safetensors', 'whisper', 'automatic-speech-recognition', 'audio', 'en', 'zh', 'de', 'es', 'ru', 'ko', 'fr', 'ja', 'pt', 'tr', 'pl', 'ca', 'nl', 'ar', 'sv', 'it', 'id', 'hi', 'fi', 'vi', 'he', 'uk', 'el', 'ms', 'cs', 'ro', 'da', 'hu', 'ta', 'no', 'th', 'ur', 'hr', 'bg', 'lt', 'la', 'mi', 'ml', 'cy', 'sk', 'te', 'fa', 'lv', 'bn', 'sr', 'az', 'sl', 'kn', 'et', 'mk', 'br', 'eu', 'is', 'hy', 'ne', 'mn', 'bs', 'kk', 'sq', 'sw', 'gl', 'mr', 'pa', 'si', 'km', 'sn', 'yo', 'so', 'af', 'oc', 'ka', 'be', 'tg', 'sd', 'gu', 'am', 'yi', 'lo', 'uz', 'fo', 'ht', 'ps', 'tk', 'nn', 'mt', 'sa', 'lb', 'my', 'bo', 'tl', 'mg', 'as', 'tt', 'haw', 'ln', 'ha', 'ba', 'jw', 'su', 'arxiv:2212.04356', 'base_model:openai/whisper-large-v3', 'base_model:finetune:openai/whisper-large-v3', 'license:mit', 'endpoints_compatible', 'region:us'], pipeline_tag='automatic-speech-recognition', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=52, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='deepseek-ai/DeepSeek-R1-Distill-Llama-8B', author=None, sha=None, created_at=datetime.datetime(2025, 1, 20, 9, 9, 42, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=817426, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=570, library_name='transformers', tags=['transformers', 'safetensors', 'llama', 'text-generation', 'conversational', 'arxiv:2501.12948', 'license:mit', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=50, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Qwen/Qwen2.5-VL-72B-Instruct', author=None, sha=None, created_at=datetime.datetime(2025, 1, 27, 4, 12, 4, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=204269, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=311, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2_5_vl', 'image-text-to-text', 'multimodal', 'conversational', 'en', 'arxiv:2309.00071', 'arxiv:2409.12191', 'arxiv:2308.12966', 'base_model:Qwen/Qwen2.5-VL-72B-Instruct', 'base_model:finetune:Qwen/Qwen2.5-VL-72B-Instruct', 'license:other', 'endpoints_compatible', 'region:us'], pipeline_tag='image-text-to-text', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=50, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Skywork/SkyReels-V1-Hunyuan-T2V', author=None, sha=None, created_at=datetime.datetime(2025, 2, 13, 8, 19, 54, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=10129, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=50, library_name='diffusers', tags=['diffusers', 'safetensors', 'text-to-video', 'en', 'base_model:tencent/HunyuanVideo', 'base_model:finetune:tencent/HunyuanVideo', 'license:apache-2.0', 'region:us'], pipeline_tag='text-to-video', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=50, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='black-forest-labs/FLUX.1-schnell', author=None, sha=None, created_at=datetime.datetime(2024, 7, 31, 19, 58, 5, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=1181701, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=3426, library_name='diffusers', tags=['diffusers', 'safetensors', 'text-to-image', 'image-generation', 'flux', 'en', 'license:apache-2.0', 'endpoints_compatible', 'diffusers:FluxPipeline', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=49, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='deepseek-ai/DeepSeek-R1-Distill-Qwen-7B', author=None, sha=None, created_at=datetime.datetime(2025, 1, 20, 9, 16, 14, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=830408, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=470, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2', 'text-generation', 'conversational', 'arxiv:2501.12948', 'license:mit', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=49, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='LatitudeGames/Wayfarer-Large-70B-Llama-3.3', author=None, sha=None, created_at=datetime.datetime(2025, 2, 14, 6, 55, 48, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=129, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=49, library_name='transformers', tags=['transformers', 'safetensors', 'llama', 'text-generation', 'text adventure', 'roleplay', 'conversational', 'en', 'base_model:meta-llama/Llama-3.3-70B-Instruct', 'base_model:finetune:meta-llama/Llama-3.3-70B-Instruct', 'license:llama3.3', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=49, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='deepseek-ai/DeepSeek-R1-Distill-Qwen-14B', author=None, sha=None, created_at=datetime.datetime(2025, 1, 20, 9, 18, 27, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=549784, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=418, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2', 'text-generation', 'conversational', 'arxiv:2501.12948', 'license:mit', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=48, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='mistralai/Mistral-7B-Instruct-v0.3', author=None, sha=None, created_at=datetime.datetime(2024, 5, 22, 9, 57, 4, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=566357, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=1388, library_name='transformers', tags=['transformers', 'safetensors', 'mistral', 'text-generation', 'conversational', 'base_model:mistralai/Mistral-7B-v0.3', 'base_model:finetune:mistralai/Mistral-7B-v0.3', 'license:apache-2.0', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=47, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='arcee-ai/Arcee-Blitz', author=None, sha=None, created_at=datetime.datetime(2025, 2, 7, 7, 55, 43, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=286, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=47, library_name='transformers', tags=['transformers', 'safetensors', 'mistral', 'text-generation', 'conversational', 'base_model:mistralai/Mistral-Small-24B-Instruct-2501', 'base_model:finetune:mistralai/Mistral-Small-24B-Instruct-2501', 'license:apache-2.0', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=47, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='HuggingFaceTB/SmolVLM2-2.2B-Instruct', author=None, sha=None, created_at=datetime.datetime(2025, 2, 8, 19, 18, 45, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=754, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=45, library_name='transformers', tags=['transformers', 'safetensors', 'smolvlm', 'image-text-to-text', 'video-text-to-text', 'en', 'dataset:HuggingFaceM4/the_cauldron', 'dataset:HuggingFaceM4/Docmatix', 'dataset:lmms-lab/LLaVA-OneVision-Data', 'dataset:lmms-lab/M4-Instruct-Data', 'dataset:HuggingFaceFV/finevideo', 'dataset:MAmmoTH-VL/MAmmoTH-VL-Instruct-12M', 'dataset:lmms-lab/LLaVA-Video-178K', 'dataset:orrzohar/Video-STaR', 'dataset:Mutonix/Vript', 'dataset:TIGER-Lab/VISTA-400K', 'dataset:Enxin/MovieChat-1K_train', 'dataset:ShareGPT4Video/ShareGPT4Video', 'base_model:HuggingFaceTB/SmolVLM-Instruct', 'base_model:finetune:HuggingFaceTB/SmolVLM-Instruct', 'license:apache-2.0', 'endpoints_compatible', 'region:us'], pipeline_tag='video-text-to-text', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=45, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='meta-llama/Llama-3.1-8B-Instruct', author=None, sha=None, created_at=datetime.datetime(2024, 7, 18, 8, 56, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=6117678, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=3657, library_name='transformers', tags=['transformers', 'safetensors', 'llama', 'text-generation', 'facebook', 'meta', 'pytorch', 'llama-3', 'conversational', 'en', 'de', 'fr', 'it', 'pt', 'hi', 'es', 'th', 'arxiv:2204.05149', 'base_model:meta-llama/Llama-3.1-8B', 'base_model:finetune:meta-llama/Llama-3.1-8B', 'license:llama3.1', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=43, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='deepseek-ai/DeepSeek-R1-Zero', author=None, sha=None, created_at=datetime.datetime(2025, 1, 20, 3, 35, 48, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=30239, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=836, library_name='transformers', tags=['transformers', 'safetensors', 'deepseek_v3', 'text-generation', 'conversational', 'custom_code', 'arxiv:2501.12948', 'license:mit', 'autotrain_compatible', 'fp8', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=43, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='BAAI/bge-m3', author=None, sha=None, created_at=datetime.datetime(2024, 1, 27, 17, 7, 29, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=2372997, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=1753, library_name='sentence-transformers', tags=['sentence-transformers', 'pytorch', 'onnx', 'xlm-roberta', 'feature-extraction', 'sentence-similarity', 'arxiv:2402.03216', 'arxiv:2004.04906', 'arxiv:2106.14807', 'arxiv:2107.05720', 'arxiv:2004.12832', 'license:mit', 'autotrain_compatible', 'text-embeddings-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='sentence-similarity', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=42, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='AIDC-AI/Ovis2-34B', author=None, sha=None, created_at=datetime.datetime(2025, 2, 10, 9, 11, 20, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=943, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=98, library_name='transformers', tags=['transformers', 'safetensors', 'ovis', 'text-generation', 'MLLM', 'image-text-to-text', 'conversational', 'custom_code', 'en', 'zh', 'dataset:AIDC-AI/Ovis-dataset', 'arxiv:2405.20797', 'license:apache-2.0', 'autotrain_compatible', 'region:us'], pipeline_tag='image-text-to-text', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=42, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='microsoft/phi-4', author=None, sha=None, created_at=datetime.datetime(2024, 12, 11, 11, 47, 29, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=610149, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=1763, library_name='transformers', tags=['transformers', 'safetensors', 'phi3', 'text-generation', 'phi', 'nlp', 'math', 'code', 'chat', 'conversational', 'custom_code', 'en', 'arxiv:2412.08905', 'license:mit', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=41, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='yentinglin/Mistral-Small-24B-Instruct-2501-reasoning', author=None, sha=None, created_at=datetime.datetime(2025, 2, 15, 17, 7, 15, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=845, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=41, library_name=None, tags=['safetensors', 'mistral', 'reasoning', 'text-generation', 'conversational', 'en', 'dataset:open-r1/OpenR1-Math-220k', 'dataset:yentinglin/s1K-1.1-trl-format', 'dataset:simplescaling/s1K-1.1', 'base_model:mistralai/Mistral-Small-24B-Instruct-2501', 'base_model:finetune:mistralai/Mistral-Small-24B-Instruct-2501', 'license:apache-2.0', 'model-index', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=41, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
# ...
#  ModelInfo(id='unsloth/DeepSeek-R1-Distill-Qwen-1.5B-GGUF', author=None, sha=None, created_at=datetime.datetime(2025, 1, 20, 13, 47, 45, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=302803, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=90, library_name='transformers', tags=['transformers', 'gguf', 'deepseek', 'qwen', 'qwen2', 'unsloth', 'en', 'arxiv:2501.12948', 'base_model:deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B', 'base_model:quantized:deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B', 'license:apache-2.0', 'endpoints_compatible', 'region:us', 'conversational'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=3, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='unsloth/DeepSeek-R1-Distill-Qwen-7B-GGUF', author=None, sha=None, created_at=datetime.datetime(2025, 1, 20, 14, 21, 41, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=349291, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=73, library_name='transformers', tags=['transformers', 'gguf', 'deepseek', 'qwen', 'qwen2', 'unsloth', 'en', 'arxiv:2501.12948', 'base_model:deepseek-ai/DeepSeek-R1-Distill-Qwen-7B', 'base_model:quantized:deepseek-ai/DeepSeek-R1-Distill-Qwen-7B', 'license:apache-2.0', 'endpoints_compatible', 'region:us', 'conversational'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=3, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='strangerzonehf/Qd-Sketch', author=None, sha=None, created_at=datetime.datetime(2025, 1, 20, 14, 26, 29, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=4542, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=30, library_name='diffusers', tags=['diffusers', 'text-to-image', 'lora', 'template:diffusion-lora', 'base_model:black-forest-labs/FLUX.1-dev', 'base_model:adapter:black-forest-labs/FLUX.1-dev', 'license:other', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=3, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='bartowski/DeepSeek-R1-Distill-Qwen-7B-GGUF', author=None, sha=None, created_at=datetime.datetime(2025, 1, 20, 14, 53, 4, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=537166, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=77, library_name=None, tags=['gguf', 'text-generation', 'base_model:deepseek-ai/DeepSeek-R1-Distill-Qwen-7B', 'base_model:quantized:deepseek-ai/DeepSeek-R1-Distill-Qwen-7B', 'endpoints_compatible', 'region:us', 'imatrix', 'conversational'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=3, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='lmstudio-community/DeepSeek-R1-Distill-Qwen-14B-GGUF', author=None, sha=None, created_at=datetime.datetime(2025, 1, 20, 14, 53, 41, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=316955, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=29, library_name=None, tags=['gguf', 'text-generation', 'base_model:deepseek-ai/DeepSeek-R1-Distill-Qwen-14B', 'base_model:quantized:deepseek-ai/DeepSeek-R1-Distill-Qwen-14B', 'endpoints_compatible', 'region:us', 'conversational'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=3, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='unsloth/DeepSeek-R1-Distill-Qwen-32B-bnb-4bit', author=None, sha=None, created_at=datetime.datetime(2025, 1, 20, 15, 0, 15, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=52222, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=21, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2', 'text-generation', 'deepseek', 'qwen', 'unsloth', 'conversational', 'en', 'base_model:deepseek-ai/DeepSeek-R1-Distill-Qwen-32B', 'base_model:quantized:deepseek-ai/DeepSeek-R1-Distill-Qwen-32B', 'license:apache-2.0', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', '4-bit', 'bitsandbytes', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=3, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='strangerzonehf/Qx-Art', author=None, sha=None, created_at=datetime.datetime(2025, 1, 20, 15, 33, 56, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=361, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=16, library_name='diffusers', tags=['diffusers', 'text-to-image', 'lora', 'template:diffusion-lora', 'base_model:black-forest-labs/FLUX.1-dev', 'base_model:adapter:black-forest-labs/FLUX.1-dev', 'license:other', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=3, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='arcee-ai/DeepSeek-R1-bf16', author=None, sha=None, created_at=datetime.datetime(2025, 1, 20, 17, 42, 26, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=2423, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=11, library_name=None, tags=['safetensors', 'deepseek_v3', 'text-generation', 'conversational', 'custom_code', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=3, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='prithivMLmods/Llama-8B-Distill-CoT', author=None, sha=None, created_at=datetime.datetime(2025, 1, 21, 6, 46, 38, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=6172, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=12, library_name='transformers', tags=['transformers', 'safetensors', 'llama', 'text-generation', 'deepseek', 'conversational', 'en', 'base_model:deepseek-ai/DeepSeek-R1-Distill-Llama-8B', 'base_model:finetune:deepseek-ai/DeepSeek-R1-Distill-Llama-8B', 'license:llama3.1', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=3, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='DAMO-NLP-SG/VideoLLaMA3-7B', author=None, sha=None, created_at=datetime.datetime(2025, 1, 21, 8, 26, 21, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=12443, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=36, library_name='transformers', tags=['transformers', 'safetensors', 'videollama3_qwen2', 'text-generation', 'multi-modal', 'large-language-model', 'video-language-model', 'visual-question-answering', 'custom_code', 'en', 'dataset:lmms-lab/LLaVA-OneVision-Data', 'dataset:allenai/pixmo-docs', 'dataset:HuggingFaceM4/Docmatix', 'dataset:lmms-lab/LLaVA-Video-178K', 'dataset:ShareGPT4Video/ShareGPT4Video', 'arxiv:2501.13106', 'arxiv:2406.07476', 'arxiv:2306.02858', 'base_model:DAMO-NLP-SG/VideoLLaMA3-7B-Image', 'base_model:finetune:DAMO-NLP-SG/VideoLLaMA3-7B-Image', 'license:apache-2.0', 'autotrain_compatible', 'region:us'], pipeline_tag='visual-question-answering', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=3, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='mradermacher/DeepSeek-R1-Distill-Qwen-7B-Uncensored-i1-GGUF', author=None, sha=None, created_at=datetime.datetime(2025, 1, 21, 20, 59, 59, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=122915, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=38, library_name='transformers', tags=['transformers', 'gguf', 'generated_from_trainer', 'en', 'dataset:Guilherme34/uncensor', 'base_model:nicoboss/DeepSeek-R1-Distill-Qwen-7B-Uncensored', 'base_model:quantized:nicoboss/DeepSeek-R1-Distill-Qwen-7B-Uncensored', 'license:mit', 'endpoints_compatible', 'region:us', 'imatrix', 'conversational'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=3, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='AtlaAI/Selene-1-Mini-Llama-3.1-8B', author=None, sha=None, created_at=datetime.datetime(2025, 1, 22, 9, 19, 44, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=3605, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=65, library_name='transformers', tags=['transformers', 'safetensors', 'llama', 'text-generation', 'atla', 'evaluation', 'llm-as-a-judge', 'meta', 'conversational', 'lm-judge', 'en', 'de', 'fr', 'it', 'pt', 'es', 'arxiv:2501.17195', 'base_model:meta-llama/Llama-3.1-8B-Instruct', 'base_model:finetune:meta-llama/Llama-3.1-8B-Instruct', 'license:apache-2.0', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=3, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='huihui-ai/DeepSeek-R1-Distill-Qwen-14B-abliterated', author=None, sha=None, created_at=datetime.datetime(2025, 1, 22, 10, 12, 47, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=837, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=26, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2', 'text-generation', 'abliterated', 'uncensored', 'conversational', 'base_model:deepseek-ai/DeepSeek-R1-Distill-Qwen-14B', 'base_model:finetune:deepseek-ai/DeepSeek-R1-Distill-Qwen-14B', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=3, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='SentientAGI/Dobby-Mini-Unhinged-Llama-3.1-8B', author=None, sha=None, created_at=datetime.datetime(2025, 1, 22, 22, 3, 19, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=3256, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=29, library_name='transformers', tags=['transformers', 'safetensors', 'llama', 'text-generation', 'Llama-3.1', 'Instruct', 'loyal AI', 'fingerprint', 'finetune', 'chat', 'gpt4', 'synthetic data', 'roleplaying', 'unhinged', 'funny', 'opinionated', 'assistant', 'companion', 'friend', 'conversational', 'en', 'arxiv:2502.07760', 'arxiv:2411.03887', 'arxiv:2406.14598', 'base_model:meta-llama/Llama-3.1-8B-Instruct', 'base_model:finetune:meta-llama/Llama-3.1-8B-Instruct', 'license:llama3.1', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=3, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='Steelskull/L3.3-Nevoria-R1-70b', author=None, sha=None, created_at=datetime.datetime(2025, 1, 23, 1, 42, 17, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=1152, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=64, library_name='transformers', tags=['transformers', 'safetensors', 'llama', 'text-generation', 'mergekit', 'merge', 'conversational', 'base_model:EVA-UNIT-01/EVA-LLaMA-3.33-70B-v0.1', 'base_model:merge:EVA-UNIT-01/EVA-LLaMA-3.33-70B-v0.1', 'base_model:Sao10K/L3.3-70B-Euryale-v2.3', 'base_model:merge:Sao10K/L3.3-70B-Euryale-v2.3', 'base_model:SicariusSicariiStuff/Negative_LLAMA_70B', 'base_model:merge:SicariusSicariiStuff/Negative_LLAMA_70B', 'base_model:TheDrummer/Anubis-70B-v1', 'base_model:merge:TheDrummer/Anubis-70B-v1', 'base_model:deepseek-ai/DeepSeek-R1-Distill-Llama-70B', 'base_model:merge:deepseek-ai/DeepSeek-R1-Distill-Llama-70B', 'base_model:nbeerbower/Llama-3.1-Nemotron-lorablated-70B', 'base_model:merge:nbeerbower/Llama-3.1-Nemotron-lorablated-70B', 'license:other', 'model-index', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=3, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ModelInfo(id='SicariusSicariiStuff/Wingless_Imp_8B', author=None, sha=None, created_at=datetime.datetime(2025, 1, 24, 9, 40, 34, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=101, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=8, library_name=None, tags=['safetensors', 'llama', 'merge', 'en', 'base_model:SicariusSicariiStuff/Dusk_Rainbow', 'base_model:merge:SicariusSicariiStuff/Dusk_Rainbow', 'base_model:SicariusSicariiStuff/Impish_Mind_8B', 'base_model:merge:SicariusSicariiStuff/Impish_Mind_8B', 'base_model:SicariusSicariiStuff/LLAMA-3_8B_Unaligned_BETA', 'base_model:merge:SicariusSicariiStuff/LLAMA-3_8B_Unaligned_BETA', 'license:llama3.1', 'region:us'], pipeline_tag=None, mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=3, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
#  ...]

# %% [markdown]
# ##
# The Hugging Face Hub provides a nice user interface for searching for models and learning more about them. At times, you may find it convenient to be able to do the same thing without leaving the development environment. Fortunately, Hugging Face also provides a Python package which allows you to find models through code.

# %%
from huggingface_hub import HfApi

api = HfApi()

# List models with text classification filter
models = api.list_models(
    filter="text-classification",  # Use string-based filtering (Other option to try might be )
    sort="downloads",
    direction=-1,  # Descending order
    limit=5
)

modelList = list(models)

# Ensure the list is not empty before accessing elements
if modelList:
    print(modelList[0])
else:
    print("No models found for text classification.")
# Out:
# ModelInfo(id='cross-encoder/ms-marco-MiniLM-L-6-v2', author=None, sha=None, created_at=datetime.datetime(2022, 3, 2, 23, 29, 5, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=12310426, downloads_all_time=None, gated=None, gguf=None, inference=None, inference_provider_mapping=None, likes=74, library_name='transformers', tags=['transformers', 'pytorch', 'jax', 'safetensors', 'bert', 'text-classification', 'license:apache-2.0', 'autotrain_compatible', 'endpoints_compatible', 'region:us'], pipeline_tag='text-classification', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=None, siblings=None, spaces=None, safetensors=None, security_repo_status=None)

# %% [markdown]
# ## Saving a Model locally

# %%
from transformers import AutoModel

modelId = "distilbert-base-uncased-finetuned-sst-2-english"

# Instantiate the AutoModel class
model = AutoModel.from_pretrained(modelId)


# Save the model to a local directory
model.save_pretrained(save_directory=f"models/{modelId}")

# %% [markdown]
# ## Using the model on single text

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline
import os

# Define paths
model_id = "distilbert-base-uncased-finetuned-sst-2-english"
save_directory = f"models/{model_id}"

# Check if the model directory exists
if not os.path.exists(save_directory):
    print(f"Model directory not found. Downloading model {model_id}...")
    
    # Create the models directory if it doesn't exist
    os.makedirs("models", exist_ok=True)
    
    # Download model and tokenizer
    model = AutoModelForSequenceClassification.from_pretrained(model_id)
    model.save_pretrained(save_directory)
    
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    tokenizer.save_pretrained(save_directory)
    
    print("Model and tokenizer downloaded successfully!")
else:
    print(f"Using locally saved model from {save_directory}")

# Load model and tokenizer from local directory
model = AutoModelForSequenceClassification.from_pretrained(save_directory)
tokenizer = AutoTokenizer.from_pretrained(save_directory)

# Create a sentiment analysis pipeline
classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)

# Perform sentiment analysis
text = "Initially, I thought of Hugging Face is just a model hosting platform, but as I explored further, I realized it was so much more."
result = classifier(text)
print(result)
# Out:
# Using locally saved model from models/distilbert-base-uncased-finetuned-sst-2-english
# Device set to use cpu
# [{'label': 'POSITIVE', 'score': 0.8700191378593445}]

# %% [markdown]
# ## Inspecting datasets
# The datasets on Hugging Face range in terms of size, information, and features. Therefore it's beneficial to inspect it before committing to loading a dataset into your environment.
#
# Let's inspect the "wikidata_extract" dataset.

# %%
# Load the module
from datasets import load_dataset_builder

# Create the dataset builder
dataset_builder = load_dataset_builder("McAuley-Lab/Amazon-Reviews-2023",  'raw_meta_All_Beauty')

# Extract the features
dataset_info = dataset_builder.info.features

# %%
print(dataset_builder.info.description)
# Out:
# Amazon Review 2023 is an updated version of the Amazon Review 2018 dataset.
# This dataset mainly includes reviews (ratings, text) and item metadata (desc-
# riptions, category information, price, brand, and images). Compared to the pre-
# vious versions, the 2023 version features larger size, newer reviews (up to Sep
# 2023), richer and cleaner meta data, and finer-grained timestamps (from day to
# milli-second).
#
# This is a subset for items in domain: All_Beauty.

# %%
print(dataset_builder.info.features)
# Out:
# {'main_category': Value(dtype='string', id=None), 'title': Value(dtype='string', id=None), 'average_rating': Value(dtype='float64', id=None), 'rating_number': Value(dtype='int64', id=None), 'features': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None), 'description': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None), 'price': Value(dtype='string', id=None), 'images': Sequence(feature={'hi_res': Value(dtype='string', id=None), 'large': Value(dtype='string', id=None), 'thumb': Value(dtype='string', id=None), 'variant': Value(dtype='string', id=None)}, length=-1, id=None), 'videos': Sequence(feature={'title': Value(dtype='string', id=None), 'url': Value(dtype='string', id=None), 'user_id': Value(dtype='string', id=None)}, length=-1, id=None), 'store': Value(dtype='string', id=None), 'categories': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None), 'details': Value(dtype='string', id=None), 'parent_asin': Value(dtype='string', id=None), 'bought_together': Value(dtype='string', id=None), 'subtitle': Value(dtype='string', id=None), 'author': Value(dtype='string', id=None)}

# %%
from huggingface_hub import HfApi

api = HfApi()

# Get datasets sorted by most downloads
datasets = api.list_datasets(sort="downloads", direction=-1, limit=10)

# Print the top 10 most downloaded datasets
print([dataset.id for dataset in datasets])
# Out:
# ['huggingface/documentation-images', 'Symato/cc', 'AquaV/genshin-voices-separated', 'hf-doc-build/doc-build-dev', 'hf-doc-build/doc-build', 'huggingchat/models-logo', 'm-a-p/FineFineWeb', 'agents-course/course-images', 'hf-internal-testing/transformers_circleci_workflow_runs', 'open-cn-llm-leaderboard/requests']

# %%
from huggingface_hub import list_datasets

datasets = list(list_datasets())  # Convert generator to a list
print([d.id for d in datasets[:10]])  # Print first 10 dataset names
# Out:
# ['facebook/natural_reasoning', 'Congliu/Chinese-DeepSeek-R1-Distill-data-110k', 'SynthLabsAI/Big-Math-RL-Verified', 'FreedomIntelligence/medical-o1-reasoning-SFT', 'allenai/olmOCR-mix-0225', 'open-r1/OpenR1-Math-220k', 'SakanaAI/AI-CUDA-Engineer-Archive', 'open-thoughts/OpenThoughts-114k', 'fka/awesome-chatgpt-prompts', 'arcinstitute/opengenome2']

# %% [markdown]
# ## Using the model on multiple data at a time using pipeline

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline
from datasets import load_dataset_builder, load_dataset
import pandas as pd
import os

# Check if the model directory exists
if not os.path.exists(save_directory):
    print(f"Model directory not found. Downloading model {model_id}...")
    
    # Create the models directory if it doesn't exist
    os.makedirs("models", exist_ok=True)
    
    # Download model and tokenizer
    model = AutoModelForSequenceClassification.from_pretrained(model_id)
    model.save_pretrained(save_directory)
    
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    tokenizer.save_pretrained(save_directory)
    
    print("Model and tokenizer downloaded successfully!")
else:
    print(f"Using locally saved model from {save_directory}")

# Create a sentiment analysis pipeline
classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)

# Load the Amazon Reviews dataset
print("Loading dataset...")
dataset = load_dataset("McAuley-Lab/Amazon-Reviews-2023", 'raw_meta_All_Beauty')

# Get the first 10 rows of the dataset
# Typically reviews are in the 'train' split, but let's check what's available
print("Available splits:", dataset.keys())

# Assuming there's a 'train' split, get the first 10 rows
split_name = 'train' if 'train' in dataset else list(dataset.keys())[0]
reviews_subset = dataset[split_name].select(range(10))

# Check available columns to find the review text column
print("Available columns:", reviews_subset.column_names)

# Usually review text is in columns like 'reviewText', 'review_text', or similar
# Let's identify a text column
text_column_candidates = ['reviewText', 'review_text', 'review', 'text']
text_column = None

for column in text_column_candidates:
    if column in reviews_subset.column_names:
        text_column = column
        break

if text_column is None:
    # If none of our guesses match, let's look for any column that might contain text
    for column in reviews_subset.column_names:
        if reviews_subset[column][0] and isinstance(reviews_subset[column][0], str) and len(reviews_subset[column][0]) > 20:
            text_column = column
            break

if text_column is None:
    print("Could not find a suitable text column. Available columns are:", reviews_subset.column_names)
    # Show a sample of each column
    for column in reviews_subset.column_names:
        print(f"Sample of '{column}': {reviews_subset[column][0]}")
else:
    print(f"Using '{text_column}' as the review text column")

    # Apply sentiment analysis on the first 10 reviews
    results = []
    for i, review in enumerate(reviews_subset[text_column]):
        if review and isinstance(review, str):
            # Some datasets might have None values or non-string types
            sentiment = classifier(review)
            results.append({
                'review_idx': i,
                'text': review[:100] + "..." if len(review) > 100 else review,  # Truncate long reviews for display
                'sentiment': sentiment[0]['label'],
                'score': sentiment[0]['score']
            })
            print(f"Review {i+1}: {review[:100]}{'...' if len(review) > 100 else ''}")
            print(f"Sentiment: {sentiment[0]['label']}, Score: {sentiment[0]['score']:.4f}")
            print("-" * 50)
        else:
            print(f"Review {i+1}: Invalid review text (None or non-string)")
            print("-" * 50)

    # Create a DataFrame for easier analysis
    results_df = pd.DataFrame(results)
    print("\nSummary of sentiment analysis:")
    print(results_df['sentiment'].value_counts())
    print("\nAverage confidence score:", results_df['score'].mean())
# Out:
# Device set to use cpu
# Using locally saved model from models/distilbert-base-uncased-finetuned-sst-2-english
# Loading dataset...
# Available splits: dict_keys(['full'])
# Available columns: ['main_category', 'title', 'average_rating', 'rating_number', 'features', 'description', 'price', 'images', 'videos', 'store', 'categories', 'details', 'parent_asin', 'bought_together', 'subtitle', 'author']
# Using 'title' as the review text column
# Review 1: Howard LC0008 Leather Conditioner, 8-Ounce (4-Pack)
# Sentiment: NEGATIVE, Score: 0.9533
# --------------------------------------------------
# Review 2: Yes to Tomatoes Detoxifying Charcoal Cleanser (Pack of 2) with Charcoal Powder, Tomato Fruit Extract...
# Sentiment: NEGATIVE, Score: 0.9818
# --------------------------------------------------
# Review 3: Eye Patch Black Adult with Tie Band (6 Per Pack)
# Sentiment: NEGATIVE, Score: 0.9753
# --------------------------------------------------
# Review 4: Tattoo Eyebrow Stickers, Waterproof Eyebrow, 4D Imitation Eyebrow Tattoos, 4D Hair-like Authentic Ey...
# Sentiment: NEGATIVE, Score: 0.6930
# --------------------------------------------------
# Review 5: Precision Plunger Bars for Cartridge Grips – 93mm – Bag of 10 Plungers
# Sentiment: NEGATIVE, Score: 0.9514
# --------------------------------------------------
# Review 6: Lurrose 100Pcs Full Cover Fake Toenails Artificial Transparent Nail Tips Nail Art for DIY
# Sentiment: NEGATIVE, Score: 0.9989
# --------------------------------------------------
# Review 7: Stain Bonnet For Baby Bonnet Silk Sleep Cap For Toddler Child Shower Cap Teens Kids
# Sentiment: NEGATIVE, Score: 0.9894
# --------------------------------------------------
# Review 8: 50 Pieces False Eyelash Packaging Box Empty Eyelash Box Plastic Eyelash Storage Case with Glitter Pa...
# Sentiment: NEGATIVE, Score: 0.9982
# --------------------------------------------------
# Review 9: Gold extatic Musk EDT 90ml
# Sentiment: NEGATIVE, Score: 0.8526
# --------------------------------------------------
# Review 10: 4 Pieces Satin Bonnet Adjustable Sleep Cap Double Layer Printed Hair Bonnet Large Reversible Sleepin...
# Sentiment: NEGATIVE, Score: 0.9131
# --------------------------------------------------
#
# Summary of sentiment analysis:
# sentiment
# NEGATIVE    10
# Name: count, dtype: int64
#
# Average confidence score: 0.9306962192058563
